# %% [markdown]
# <a href="https://colab.research.google.com/github/min02yam/R-study/blob/main/%EC%97%B0%EC%8A%B5/tm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2022.05.28<br>

# %%
install.packages("tm")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘NLP’, ‘Rcpp’, ‘slam’, ‘BH’

# %%
library(tm)

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ ggplot2::annotate() masks NLP::annotate()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::lag()        masks stats::lag()

# %%
system("gdown --id 1PfS8yTaJ0p5Pn62HdlQbP0ZV5ZHuvLzV")

# %%
Sys.setlocale("LC_ALL","korean")
# Out:
# Warning message in Sys.setlocale("LC_ALL", "korean"):
# "OS reports request to set locale to "korean" cannot be honored"
# [1] ""

# %%
Sys.getlocale()
Sys.setlocale("LC_ALL","C") # 강제 언어 삭제
data1 <- read.csv('/content/result_reshape.csv', na.strings=NA, header = T, sep=",",encoding = "UTF-8") #file read 시, UTF-8로 인코딩
Sys.setlocale("LC_ALL","Korean") # 언어 다시 한글로
# Out:
# [1] "LC_CTYPE=en_US.UTF-8;LC_NUMERIC=C;LC_TIME=en_US.UTF-8;LC_COLLATE=en_US.UTF-8;LC_MONETARY=en_US.UTF-8;LC_MESSAGES=en_US.UTF-8;LC_PAPER=en_US.UTF-8;LC_NAME=C;LC_ADDRESS=C;LC_TELEPHONE=C;LC_MEASUREMENT=en_US.UTF-8;LC_IDENTIFICATION=C"
# [1] "LC_CTYPE=C;LC_NUMERIC=C;LC_TIME=C;LC_COLLATE=C;LC_MONETARY=C;LC_MESSAGES=en_US.UTF-8;LC_PAPER=en_US.UTF-8;LC_NAME=C;LC_ADDRESS=C;LC_TELEPHONE=C;LC_MEASUREMENT=en_US.UTF-8;LC_IDENTIFICATION=C"
# Warning message in Sys.setlocale("LC_ALL", "Korean"):
# "OS reports request to set locale to "Korean" cannot be honored"
# [1] ""

# %%
df=read.csv('/content/result_reshape.csv', encoding = "UTF-8")

# %%
df%>%head()
# Out:
#   X.c0..U.03B9..b0.
# 1 <c1><U+04B8><a3><b5><f0>
# 2 <bd><ba><U+01BC><ba><ec> <bd><ba><c7><U+02B9><f6><b1><d7>,<b9><U+06B1><e2><c5><c3>
# 3 <U+0232><c0><U+03B9><fc>
# 4
# 5
# 6 <b0><ed><b7><b9><bf><a1><b4><d9> <c8><f7><b7><ce><U+012B><c1><ee>,<c3><U+05B5><bf><c8><c6>,<b7><U+0903FFCF>,<b1><U+8F3A><U+0066>,<bd><U+017F><ac><bd><c4>,<c0><cc><c7><U+063F><b5>,<c0><U+033C><f6><bc><ba>,<b9><da><c8><f1><b0><ef>,<b9><da><c2><U+0903FB00><cc><U+0064><c0><e7>,<c5><e8>,<b1><e8><b0><e6><bf><U+0802CAFF><U+08033B00><U+033D><c2><c1><d8>,<b9><U+06B9><U+3CDAC025><c7><d7><c1><d8>,<b9><da><c8><c6><U+0064>
#   X.U.0027..U.0121.
# 1
# 2 <c6><U+0235><b5>
# 3
# 4 <bc><ba><bc><f6><b5><bf>
# 5 <c6><U+0235><b5>
# 6 <ba><U+03F9><cc>,<U+0133><b3><aa><b4><d9>,<b5><b6><c0><cf>,<b9><U+0331><b9>,<bd><ba><bf><U+CF2D><bf><ef>,<c0><U+03FA><bb>,<c1><U+07F1><b9>,<U+002F><b7><b4>,<U+022B><c4><e1>,<b3><U+05F4><U+0A037D65>,<c6><U+0237><b9>,<be><U+01BD><U+00FE><c6>,<b0><ad>,<bc><ad><b1><b8><b1><c7>,<U+0223><c1><d6>
# ...

# %%
https://drive.google.com/file/d/1PfS8yTaJ0p5Pn62HdlQbP0ZV5ZHuvLzV/view?usp=sharing

# %%
year<-tm_map( VCorpus(VectorSource(df[,3])),  removePunctuation)

# %% [markdown]
# # 1. 라이브러리 및 데이터 로드

# %%
install.packages(c("tidymodels","tidyverse","lubridate","skimr","magrittr","data.table","gridExtra","pacman"))
pacman::p_load("tidymodels","tidyverse","lubridate","skimr","magrittr","data.table","gridExtra","pacman")
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("GGally") ; library(GGally)

# %%
theme_set(theme_bw())

# %%
system("gdown --id 17bke1KhCQFDjVToiNybtczlKqkWmWlvg")

# %%
c
# Out:
# Rows: 119390 Columns: 17
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (4): hotel_type, meal, reserved_room_type, assigned_room_type
# dbl (13): is_canceled, lead_time, stays_in_weekend_nights, stays_in_week_nig...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#티블로 변경
tib<-as_tibble(df)
